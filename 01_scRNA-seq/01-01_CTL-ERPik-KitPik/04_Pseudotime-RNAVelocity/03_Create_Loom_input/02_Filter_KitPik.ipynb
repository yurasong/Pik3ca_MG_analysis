# %%
import scvelo as scv
import pandas as pd

# %%
adata = scv.read("../01_Input_file/KitPik_raw.loom", cache=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata.var_names_make_unique()   # fix duplicate gene names

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [possorted_genome_bam_Q7E7W:AAAGGATTCGTAACTGx, possorted_genome_bam_Q7E7W:AAACGAATCCAGCAATx, possorted_genome_bam_Q7E7W:AAACGCTTCGAACTCAx, possorted_genome_bam_Q7E7W:AAAGGGCCAAGCGGATx, possorted_genome_bam_Q7E7W:AAAGAACTCGAACCTAx, possorted_genome_bam_Q7E7W:AAAGGATCACCCTTACx, possorted_genome_bam_Q7E7W:AAAGGGCAGTTCCATGx, possorted_genome_bam_Q7E7W:AAAGGATGTATTCCGAx, possorted_genome_bam_Q7E7W:AAACCCATCCAACCGGx, possorted_genome_bam_Q7E7W:AAAGGATGTGTCCGTGx, possorted_genome_bam_Q7E7W:AAACCCAGTAATTGGAx, possorted_genome_bam_Q7E7W:AAAGGATCAGAGTGACx, possorted_genome_bam_Q7E7W:AAAGGATGTGACAGGTx, possorted_genome_bam_Q7E7W:AAAGGGCCAGCAGACAx, possorted_genome_bam_Q7E7W:AAACCCAAGTAGGTTAx, possorted_genome_bam_Q7E7W:AAACGAATCTCATGCCx, possorted_genome_bam_Q7E7W:AAAGAACGTAACGGTGx, possorted_genome_bam_Q7E7W:AAAGGGCAGTTATGGAx, possorted_genome_bam_Q7E7W:AAACGAAGTACCATACx, possorted_genome_bam_Q7E7W:AAACGCTGTATATGGAx, possorted_genome_bam_Q7E7W:AAACGCTAGAGCTGACx, possorted_genome_bam_Q7E7W:AAACGAAGTTTATGCGx, possorted_genome_bam_Q7E7W:AAACGCTTCTCGCTTGx, possorted_genome_bam_Q7E7W:AAACGAATCTTGAACGx, possorted_genome_bam_Q7E7W:AAAGAACAGTAAACTGx, possorted_genome_bam_Q7E7W:AAAGAACTCTTACACTx, possorted_genome_bam_Q7E7W:AAACGCTTCGTGGCGTx, possorted_genome_bam_Q7E7W:AAAGGGCCATAACAGAx, possorted_genome_bam_Q7E7W:AAAGGATTCTCGCTTGx, possorted_genome_bam_Q7E7W:AAACGAACAGGTTCCGx, possorted_genome_bam_Q7E7W:AAAGGATAGTCGAGGTx, possorted_genome_bam_Q7E7W:AAAGGATTCTACAGGTx, possorted_genome_bam_Q7E7W:AAAGAACTCCCGAACGx, possorted_genome_bam_Q7E7W:AAAGGGCCAACAGATAx, possorted_genome_bam_Q7E7W:AAAGGGCCAGGGAATCx, possorted_genome_bam_Q7E7W:AAAGGGCTCATAGGCTx, possorted_genome_bam_Q7E7W:AAAGAACTCCTCACTGx, possorted_genome_bam_Q7E7W:AAACCCAGTTATTCTCx, possorted_genome_bam_Q7E7W:AAAGGATCATGTCTAGx, possorted_genome_bam_Q7E7W:AAACGAACACGTAGTTx, possorted_genome_bam_Q7E7W:AAACGAAGTGGGACATx, possorted_genome_bam_Q7E7W:AAACGAATCTCGTGAAx, possorted_genome_bam_Q7E7W:AAAGAACGTACCATACx, possorted_genome_bam_Q7E7W:AAAGGATGTCCTTGTCx, possorted_genome_bam_Q7E7W:AAACCCACATCCTAAGx, possorted_genome_bam_Q7E7W:AAAGGATTCTCGTGGGx, possorted_genome_bam_Q7E7W:AAACGCTGTAGAGCTGx, possorted_genome_bam_Q7E7W:AAAGAACAGGTGAGAAx, possorted_genome_bam_Q7E7W:AAACCCACATGGAATAx, possorted_genome_bam_Q7E7W:AAAGAACTCATTGCTTx, possorted_genome_bam_Q7E7W:AAAGGATAGTAGGCCAx, possorted_genome_bam_Q7E7W:AAACGCTGTTCTTAGGx, possorted_genome_bam_Q7E7W:AAAGAACGTCAGTTTGx, possorted_genome_bam_Q7E7W:AAACGCTTCTCTCCGAx, possorted_genome_bam_Q7E7W:AAACCCACAGTGCCTGx, possorted_genome_bam_Q7E7W:AAACGCTCATGGCACCx, possorted_genome_bam_Q7E7W:AAAGGGCAGAAGCCTGx, possorted_genome_bam_Q7E7W:AAACGCTGTTACCTTTx, possorted_genome_bam_Q7E7W:AAAGAACGTCATAGTCx, possorted_genome_bam_Q7E7W:AAAGGGCGTCGAGTGAx, possorted_genome_bam_Q7E7W:AAAGGATCACGGATCCx, possorted_genome_bam_Q7E7W:AAACGCTGTCTGTAGTx, possorted_genome_bam_Q7E7W:AAAGGATCAGCATTGTx, possorted_genome_bam_Q7E7W:AAAGGGCGTGCGACAAx, possorted_genome_bam_Q7E7W:AAAGGATAGGCGACATx, possorted_genome_bam_Q7E7W:AAAGGGCCAATAAGGTx, possorted_genome_bam_Q7E7W:AAACGAAGTGGATCAGx, possorted_genome_bam_Q7E7W:AAACCCAAGTGCCGAAx, possorted_genome_bam_Q7E7W:AAACGAAGTTGAGAGCx, possorted_genome_bam_Q7E7W:AAACGCTTCTCAACGAx, possorted_genome_bam_Q7E7W:AAACGAATCTTGCAAGx, possorted_genome_bam_Q7E7W:AAACGAATCTAGTTCTx, possorted_genome_bam_Q7E7W:AAACCCAAGCCTAACTx, possorted_genome_bam_Q7E7W:AAAGGGCAGAGCACTGx, possorted_genome_bam_Q7E7W:AAACGCTTCGTAGTGTx, possorted_genome_bam_Q7E7W:AAACGAATCTATTTCGx, possorted_genome_bam_Q7E7W:AAACGCTGTTAGAAGTx, possorted_genome_bam_Q7E7W:AAAGGGCCACCGGCTAx, possorted_genome_bam_Q7E7W:AAACGAAGTCAACACTx, possorted_genome_bam_Q7E7W:AAACGCTTCATTGCTTx, possorted_genome_bam_Q7E7W:AAACGAACAACAGCTTx, possorted_genome_bam_Q7E7W:AAAGAACTCGTACACAx, possorted_genome_bam_Q7E7W:AAAGGATAGATCCAAAx, possorted_genome_bam_Q7E7W:AAACCCACATCCAATGx, possorted_genome_bam_Q7E7W:AAACGCTAGTGCCGAAx, possorted_genome_bam_Q7E7W:AAACGAAGTGTCCATAx, possorted_genome_bam_Q7E7W:AAACGCTGT ...
#
# [12929 rows x 0 columns]

# %%
cell_meta = pd.read_csv("meta_Kit_Pik.csv")
cell_umap = pd.read_csv("umap_Kit_Pik.csv", sep=',')
cell_meta_umap = pd.merge(cell_meta, cell_umap, on="CellID", how="inner")

cell_meta_umap
# Out:
#                     CellID   cell_type    umap_1    umap_2
# 0     AAACCCAAGCCTAACT-1_2  LC_ER-_LuP  4.340409  3.598367
# 1     AAACCCAAGTAGGTTA-1_2  LC_ER-_LuP  4.656558  3.029929
# 2     AAACCCAAGTGCCGAA-1_2  LC_ER-_LaP  5.102678  7.060255
# 3     AAACCCACAGCAGATG-1_2  LC_ER-_LuP  5.902091  4.927938
# 4     AAACCCACATGGAATA-1_2  LC_ER-_LuP  3.184937  3.071098
# ...                    ...         ...       ...       ...
# 6017  TTTGTTGGTTTCGCTC-1_2  LC_ER-_LuP  5.596863  4.484584
# 6018  TTTGTTGTCCCATAAG-1_2  LC_ER-_LuP  2.975631  2.102163
# 6019  TTTGTTGTCCCTTCCC-1_2  LC_ER-_LaP  2.599695  5.917958
# 6020  TTTGTTGTCGTTGCCT-1_2  LC_ER-_LuP  5.374636  2.943366
# 6021  TTTGTTGTCTCACTCG-1_2  LC_ER-_LaP  2.488570  7.228754
#
# [6022 rows x 4 columns]

# %%
cell_meta_umap.index = cell_meta_umap['CellID']
cell_meta_umap = cell_meta_umap.drop(['CellID'], axis=1)

cell_meta_umap
# Out:
#                        cell_type    umap_1    umap_2
# CellID
# AAACCCAAGCCTAACT-1_2  LC_ER-_LuP  4.340409  3.598367
# AAACCCAAGTAGGTTA-1_2  LC_ER-_LuP  4.656558  3.029929
# AAACCCAAGTGCCGAA-1_2  LC_ER-_LaP  5.102678  7.060255
# AAACCCACAGCAGATG-1_2  LC_ER-_LuP  5.902091  4.927938
# AAACCCACATGGAATA-1_2  LC_ER-_LuP  3.184937  3.071098
# ...                          ...       ...       ...
# TTTGTTGGTTTCGCTC-1_2  LC_ER-_LuP  5.596863  4.484584
# TTTGTTGTCCCATAAG-1_2  LC_ER-_LuP  2.975631  2.102163
# TTTGTTGTCCCTTCCC-1_2  LC_ER-_LaP  2.599695  5.917958
# TTTGTTGTCGTTGCCT-1_2  LC_ER-_LuP  5.374636  2.943366
# TTTGTTGTCTCACTCG-1_2  LC_ER-_LaP  2.488570  7.228754
#
# [6022 rows x 3 columns]

# %%
# loop for cellID

def add_scvelo_ID(df):
    df = df.copy()
    ids = []
    for idx in df.index.astype(str):
        barcode16 = idx.split("-")[0][:16]
        ids.append(f"possorted_genome_bam_Q7E7W:{barcode16}x")
    df["scvelo_cellID"] = ids
    return df

# %%
new_cell_meta_umap = add_scvelo_ID(cell_meta_umap)
new_cell_meta_umap
# Out:
#                        cell_type    umap_1    umap_2  \
# CellID
# AAACCCAAGCCTAACT-1_2  LC_ER-_LuP  4.340409  3.598367
# AAACCCAAGTAGGTTA-1_2  LC_ER-_LuP  4.656558  3.029929
# AAACCCAAGTGCCGAA-1_2  LC_ER-_LaP  5.102678  7.060255
# AAACCCACAGCAGATG-1_2  LC_ER-_LuP  5.902091  4.927938
# AAACCCACATGGAATA-1_2  LC_ER-_LuP  3.184937  3.071098
# ...                          ...       ...       ...
# TTTGTTGGTTTCGCTC-1_2  LC_ER-_LuP  5.596863  4.484584
# TTTGTTGTCCCATAAG-1_2  LC_ER-_LuP  2.975631  2.102163
# TTTGTTGTCCCTTCCC-1_2  LC_ER-_LaP  2.599695  5.917958
# TTTGTTGTCGTTGCCT-1_2  LC_ER-_LuP  5.374636  2.943366
# TTTGTTGTCTCACTCG-1_2  LC_ER-_LaP  2.488570  7.228754
#
#                                                      scvelo_cellID
# CellID
# AAACCCAAGCCTAACT-1_2  possorted_genome_bam_Q7E7W:AAACCCAAGCCTAACTx
# AAACCCAAGTAGGTTA-1_2  possorted_genome_bam_Q7E7W:AAACCCAAGTAGGTTAx
# AAACCCAAGTGCCGAA-1_2  possorted_genome_bam_Q7E7W:AAACCCAAGTGCCGAAx
# AAACCCACAGCAGATG-1_2  possorted_genome_bam_Q7E7W:AAACCCACAGCAGATGx
# AAACCCACATGGAATA-1_2  possorted_genome_bam_Q7E7W:AAACCCACATGGAATAx
# ...                                                            ...
# TTTGTTGGTTTCGCTC-1_2  possorted_genome_bam_Q7E7W:TTTGTTGGTTTCGCTCx
# TTTGTTGTCCCATAAG-1_2  possorted_genome_bam_Q7E7W:TTTGTTGTCCCATAAGx
# TTTGTTGTCCCTTCCC-1_2  possorted_genome_bam_Q7E7W:TTTGTTGTCCCTTCCCx
# TTTGTTGTCGTTGCCT-1_2  possorted_genome_bam_Q7E7W:TTTGTTGTCGTTGCCTx
# TTTGTTGTCTCACTCG-1_2  possorted_genome_bam_Q7E7W:TTTGTTGTCTCACTCGx
#
# [6022 rows x 4 columns]

# %%
valid_cells = new_cell_meta_umap["scvelo_cellID"].values
adata_sub = adata[adata.obs_names.isin(valid_cells)].copy()

# %%
print(f"Original cells: {adata.n_obs}, Filtered cells: {adata_sub.n_obs}")
# Out:
# Original cells: 12929, Filtered cells: 6022

# %%
new_cell_meta_umap.index = new_cell_meta_umap['scvelo_cellID']
new_cell_meta_umap = new_cell_meta_umap.drop(['scvelo_cellID'], axis=1)

# %%
new_cell_meta_umap
# Out:
#                                                cell_type    umap_1    umap_2
# scvelo_cellID
# possorted_genome_bam_Q7E7W:AAACCCAAGCCTAACTx  LC_ER-_LuP  4.340409  3.598367
# possorted_genome_bam_Q7E7W:AAACCCAAGTAGGTTAx  LC_ER-_LuP  4.656558  3.029929
# possorted_genome_bam_Q7E7W:AAACCCAAGTGCCGAAx  LC_ER-_LaP  5.102678  7.060255
# possorted_genome_bam_Q7E7W:AAACCCACAGCAGATGx  LC_ER-_LuP  5.902091  4.927938
# possorted_genome_bam_Q7E7W:AAACCCACATGGAATAx  LC_ER-_LuP  3.184937  3.071098
# ...                                                  ...       ...       ...
# possorted_genome_bam_Q7E7W:TTTGTTGGTTTCGCTCx  LC_ER-_LuP  5.596863  4.484584
# possorted_genome_bam_Q7E7W:TTTGTTGTCCCATAAGx  LC_ER-_LuP  2.975631  2.102163
# possorted_genome_bam_Q7E7W:TTTGTTGTCCCTTCCCx  LC_ER-_LaP  2.599695  5.917958
# possorted_genome_bam_Q7E7W:TTTGTTGTCGTTGCCTx  LC_ER-_LuP  5.374636  2.943366
# possorted_genome_bam_Q7E7W:TTTGTTGTCTCACTCGx  LC_ER-_LaP  2.488570  7.228754
#
# [6022 rows x 3 columns]

# %%
adata_sub.obs = adata_sub.obs.join(new_cell_meta_umap, how="left")

# %%
print(adata_sub.obs.head())
# Out:
#                                                cell_type    umap_1    umap_2
# CellID
# possorted_genome_bam_Q7E7W:AAACGAATCCAGCAATx  LC_ER-_LaP  2.019011  3.735029
# possorted_genome_bam_Q7E7W:AAACGCTTCGAACTCAx  LC_ER-_LaP  5.438486  6.903892
# possorted_genome_bam_Q7E7W:AAAGAACTCGAACCTAx  LC_ER-_LaP  4.851584  7.372660
# possorted_genome_bam_Q7E7W:AAAGGATCACCCTTACx  LC_ER-_LuP  3.961037  3.916472
# possorted_genome_bam_Q7E7W:AAACCCATCCAACCGGx  LC_ER-_LaP  2.804697  5.086157

# %%
adata_sub.write_loom("filtered_Kit_Pik.loom")
