# %%
import scvelo as scv
import pandas as pd

# %%
adata = scv.read("../01_Input_file/ERPik_raw.loom", cache=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata.var_names_make_unique()   # fix duplicate gene names

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [possorted_genome_bam_W83LZ:AAAGGATTCAGCCTTCx, possorted_genome_bam_W83LZ:AAACGAACAGCTGTCGx, possorted_genome_bam_W83LZ:AAAGAACCATCTTTCAx, possorted_genome_bam_W83LZ:AAACGAAGTCATATGCx, possorted_genome_bam_W83LZ:AAACCCACATCCCACTx, possorted_genome_bam_W83LZ:AAACCCACAGCCCACAx, possorted_genome_bam_W83LZ:AAACCCAAGGGTGAGGx, possorted_genome_bam_W83LZ:AAAGAACTCTTAGGACx, possorted_genome_bam_W83LZ:AAACCCATCTCTGAGAx, possorted_genome_bam_W83LZ:AAAGGATTCAGCGCACx, possorted_genome_bam_W83LZ:AAACCCAAGCCTATTGx, possorted_genome_bam_W83LZ:AAAGGATTCTATCGCCx, possorted_genome_bam_W83LZ:AAACGCTCATGACTGTx, possorted_genome_bam_W83LZ:AAAGGATGTTGAAGTAx, possorted_genome_bam_W83LZ:AAACCCATCGAGCTGCx, possorted_genome_bam_W83LZ:AAACGCTAGTTTCGACx, possorted_genome_bam_W83LZ:AAACGCTCAACCAGAGx, possorted_genome_bam_W83LZ:AAACGAAAGCAAGTCGx, possorted_genome_bam_W83LZ:AAAGGATCAGAATGTAx, possorted_genome_bam_W83LZ:AAACGCTAGACCCTTAx, possorted_genome_bam_W83LZ:AAACGCTCAATCACGTx, possorted_genome_bam_W83LZ:AAAGAACAGCTCGGCTx, possorted_genome_bam_W83LZ:AAAGAACCACCAGACCx, possorted_genome_bam_W83LZ:AAAGGATAGTAAACACx, possorted_genome_bam_W83LZ:AAACGAATCCTGTTATx, possorted_genome_bam_W83LZ:AAAGGATGTATTGAGAx, possorted_genome_bam_W83LZ:AAAGAACCATGTTCAGx, possorted_genome_bam_W83LZ:AAAGGATGTCGTGATTx, possorted_genome_bam_W83LZ:AAACGCTTCCACATAGx, possorted_genome_bam_W83LZ:AAAGAACAGCACTCTAx, possorted_genome_bam_W83LZ:AAACCCATCGAGCCTGx, possorted_genome_bam_W83LZ:AAAGGATTCGAGCCTGx, possorted_genome_bam_W83LZ:AAACGAATCCGCAGTGx, possorted_genome_bam_W83LZ:AAACGCTCATCCTGTCx, possorted_genome_bam_W83LZ:AAAGGATTCTACACTTx, possorted_genome_bam_W83LZ:AAAGGATAGTGAGTTAx, possorted_genome_bam_W83LZ:AAACGAACACTAGGTTx, possorted_genome_bam_W83LZ:AAAGAACGTGATCGTTx, possorted_genome_bam_W83LZ:AAAGGATGTCCCTCATx, possorted_genome_bam_W83LZ:AAACGCTCACCGGTCAx, possorted_genome_bam_W83LZ:AAACGAATCCACTAGAx, possorted_genome_bam_W83LZ:AAAGAACGTCGGTAAGx, possorted_genome_bam_W83LZ:AAACGCTCAAGTTCGTx, possorted_genome_bam_W83LZ:AAAGGATTCTGGACCGx, possorted_genome_bam_W83LZ:AAACGAAGTACCCGACx, possorted_genome_bam_W83LZ:AAACGCTCACTGCGACx, possorted_genome_bam_W83LZ:AAACGCTGTTCTTAGGx, possorted_genome_bam_W83LZ:AAACGCTCAACAAAGTx, possorted_genome_bam_W83LZ:AAACCCACAAGCAGGTx, possorted_genome_bam_W83LZ:AAACGCTGTTCGATTGx, possorted_genome_bam_W83LZ:AAAGAACTCCGCTGTTx, possorted_genome_bam_W83LZ:AAACCCACAGGTCAAGx, possorted_genome_bam_W83LZ:AAAGAACTCACCTGGGx, possorted_genome_bam_W83LZ:AAAGGATCAGGCATGAx, possorted_genome_bam_W83LZ:AAACGCTTCAAGGCTTx, possorted_genome_bam_W83LZ:AAAGAACAGGGTAATTx, possorted_genome_bam_W83LZ:AAAGGATAGAGAACCCx, possorted_genome_bam_W83LZ:AAAGGATAGTGGACGTx, possorted_genome_bam_W83LZ:AAACCCATCCACCTCAx, possorted_genome_bam_W83LZ:AAACGCTCAAGGCCTCx, possorted_genome_bam_W83LZ:AAACGAATCACTGGTAx, possorted_genome_bam_W83LZ:AAAGAACGTGAAAGTTx, possorted_genome_bam_W83LZ:AAACGAATCGGCGATCx, possorted_genome_bam_W83LZ:AAACCCAGTGTGACCCx, possorted_genome_bam_W83LZ:AAACGCTCAACTTGCAx, possorted_genome_bam_W83LZ:AAACGCTTCCTCGCATx, possorted_genome_bam_W83LZ:AAAGAACGTCTGTAGTx, possorted_genome_bam_W83LZ:AAACGAAGTACTCGCGx, possorted_genome_bam_W83LZ:AAAGGATCAGCGAGTAx, possorted_genome_bam_W83LZ:AAAGGATTCTGCATGAx, possorted_genome_bam_W83LZ:AAACCCACACCTGCGAx, possorted_genome_bam_W83LZ:AAAGGATAGATAACACx, possorted_genome_bam_W83LZ:AAACCCAGTAATGCGGx, possorted_genome_bam_W83LZ:AAAGAACGTATCACGTx, possorted_genome_bam_W83LZ:AAACGAATCTCCGATCx, possorted_genome_bam_W83LZ:AAAGAACTCGGCATTAx, possorted_genome_bam_W83LZ:AAACCCAGTTCGGGTCx, possorted_genome_bam_W83LZ:AAAGAACCAGGCTTGCx, possorted_genome_bam_W83LZ:AAACGAAAGGAACATTx, possorted_genome_bam_W83LZ:AAACGCTAGGGTGGGAx, possorted_genome_bam_W83LZ:AAACGAACAAAGCGTGx, possorted_genome_bam_W83LZ:AAACGCTCAAGACAATx, possorted_genome_bam_W83LZ:AAAGGATGTACCTAGTx, possorted_genome_bam_W83LZ:AAACGCTAGATGGGCTx, possorted_genome_bam_W83LZ:AAACCCACACCCAAGCx, possorted_genome_bam_W83LZ:AAACGAATCGGAGCAAx, possorted_genome_bam_W83LZ:AAACCCATC ...
#
# [20872 rows x 0 columns]

# %%
cell_meta = pd.read_csv("meta_ER_Pik.csv")
cell_umap = pd.read_csv("umap_ER_Pik.csv", sep=',')
cell_meta_umap = pd.merge(cell_meta, cell_umap, on="CellID", how="inner")

cell_meta_umap
# Out:
#                     CellID     cell_type    umap_1    umap_2
# 0     AAACCCAAGGTTACAA-1_3           Myo -7.883332 -8.220748
# 1     AAACCCACACCCAAGC-1_3       Late_HY -7.431042  0.378131
# 2     AAACCCACACCTGCGA-1_3       Late_HY -6.337716  2.035150
# 3     AAACCCACATCCCACT-1_3       Late_HY -6.760766  1.335699
# 4     AAACGAAAGCGGCTCT-1_3       Late_HY -6.763875  2.675161
# ...                    ...           ...       ...       ...
# 8664  TTTGTTGCATCGAAGG-1_3   LC_ER+_Sca1 -1.967123 -7.662631
# 8665  TTTGTTGGTTAGAGTA-1_3       Late_HY -5.430854  1.680624
# 8666  TTTGTTGTCCTTCTGG-1_3       Late_HY -7.170263  3.242602
# 8667  TTTGTTGTCGCAAGAG-1_3  LC_ER+_Foxa1  1.734159 -7.383719
# 8668  TTTGTTGTCTATTGTC-1_3      Early_HY -0.269771 -3.924437
#
# [8669 rows x 4 columns]

# %%
cell_meta_umap.index = cell_meta_umap['CellID']
cell_meta_umap = cell_meta_umap.drop(['CellID'], axis=1)

cell_meta_umap
# Out:
#                          cell_type    umap_1    umap_2
# CellID
# AAACCCAAGGTTACAA-1_3           Myo -7.883332 -8.220748
# AAACCCACACCCAAGC-1_3       Late_HY -7.431042  0.378131
# AAACCCACACCTGCGA-1_3       Late_HY -6.337716  2.035150
# AAACCCACATCCCACT-1_3       Late_HY -6.760766  1.335699
# AAACGAAAGCGGCTCT-1_3       Late_HY -6.763875  2.675161
# ...                            ...       ...       ...
# TTTGTTGCATCGAAGG-1_3   LC_ER+_Sca1 -1.967123 -7.662631
# TTTGTTGGTTAGAGTA-1_3       Late_HY -5.430854  1.680624
# TTTGTTGTCCTTCTGG-1_3       Late_HY -7.170263  3.242602
# TTTGTTGTCGCAAGAG-1_3  LC_ER+_Foxa1  1.734159 -7.383719
# TTTGTTGTCTATTGTC-1_3      Early_HY -0.269771 -3.924437
#
# [8669 rows x 3 columns]

# %%
# loop for cellID

def add_scvelo_ID(df):
    df = df.copy()
    ids = []
    for idx in df.index.astype(str):
        barcode16 = idx.split("-")[0][:16]
        ids.append(f"possorted_genome_bam_W83LZ:{barcode16}x")
    df["scvelo_cellID"] = ids
    return df

# %%
new_cell_meta_umap = add_scvelo_ID(cell_meta_umap)
new_cell_meta_umap
# Out:
#                          cell_type    umap_1    umap_2  \
# CellID
# AAACCCAAGGTTACAA-1_3           Myo -7.883332 -8.220748
# AAACCCACACCCAAGC-1_3       Late_HY -7.431042  0.378131
# AAACCCACACCTGCGA-1_3       Late_HY -6.337716  2.035150
# AAACCCACATCCCACT-1_3       Late_HY -6.760766  1.335699
# AAACGAAAGCGGCTCT-1_3       Late_HY -6.763875  2.675161
# ...                            ...       ...       ...
# TTTGTTGCATCGAAGG-1_3   LC_ER+_Sca1 -1.967123 -7.662631
# TTTGTTGGTTAGAGTA-1_3       Late_HY -5.430854  1.680624
# TTTGTTGTCCTTCTGG-1_3       Late_HY -7.170263  3.242602
# TTTGTTGTCGCAAGAG-1_3  LC_ER+_Foxa1  1.734159 -7.383719
# TTTGTTGTCTATTGTC-1_3      Early_HY -0.269771 -3.924437
#
#                                                      scvelo_cellID
# CellID
# AAACCCAAGGTTACAA-1_3  possorted_genome_bam_W83LZ:AAACCCAAGGTTACAAx
# AAACCCACACCCAAGC-1_3  possorted_genome_bam_W83LZ:AAACCCACACCCAAGCx
# AAACCCACACCTGCGA-1_3  possorted_genome_bam_W83LZ:AAACCCACACCTGCGAx
# AAACCCACATCCCACT-1_3  possorted_genome_bam_W83LZ:AAACCCACATCCCACTx
# AAACGAAAGCGGCTCT-1_3  possorted_genome_bam_W83LZ:AAACGAAAGCGGCTCTx
# ...                                                            ...
# TTTGTTGCATCGAAGG-1_3  possorted_genome_bam_W83LZ:TTTGTTGCATCGAAGGx
# TTTGTTGGTTAGAGTA-1_3  possorted_genome_bam_W83LZ:TTTGTTGGTTAGAGTAx
# TTTGTTGTCCTTCTGG-1_3  possorted_genome_bam_W83LZ:TTTGTTGTCCTTCTGGx
# TTTGTTGTCGCAAGAG-1_3  possorted_genome_bam_W83LZ:TTTGTTGTCGCAAGAGx
# TTTGTTGTCTATTGTC-1_3  possorted_genome_bam_W83LZ:TTTGTTGTCTATTGTCx
#
# [8669 rows x 4 columns]

# %%
valid_cells = new_cell_meta_umap["scvelo_cellID"].values
adata_sub = adata[adata.obs_names.isin(valid_cells)].copy()

# %%
print(f"Original cells: {adata.n_obs}, Filtered cells: {adata_sub.n_obs}")
# Out:
# Original cells: 20872, Filtered cells: 8669

# %%
new_cell_meta_umap.index = new_cell_meta_umap['scvelo_cellID']
new_cell_meta_umap = new_cell_meta_umap.drop(['scvelo_cellID'], axis=1)

# %%
new_cell_meta_umap
# Out:
#                                                  cell_type    umap_1    umap_2
# scvelo_cellID
# possorted_genome_bam_W83LZ:AAACCCAAGGTTACAAx           Myo -7.883332 -8.220748
# possorted_genome_bam_W83LZ:AAACCCACACCCAAGCx       Late_HY -7.431042  0.378131
# possorted_genome_bam_W83LZ:AAACCCACACCTGCGAx       Late_HY -6.337716  2.035150
# possorted_genome_bam_W83LZ:AAACCCACATCCCACTx       Late_HY -6.760766  1.335699
# possorted_genome_bam_W83LZ:AAACGAAAGCGGCTCTx       Late_HY -6.763875  2.675161
# ...                                                    ...       ...       ...
# possorted_genome_bam_W83LZ:TTTGTTGCATCGAAGGx   LC_ER+_Sca1 -1.967123 -7.662631
# possorted_genome_bam_W83LZ:TTTGTTGGTTAGAGTAx       Late_HY -5.430854  1.680624
# possorted_genome_bam_W83LZ:TTTGTTGTCCTTCTGGx       Late_HY -7.170263  3.242602
# possorted_genome_bam_W83LZ:TTTGTTGTCGCAAGAGx  LC_ER+_Foxa1  1.734159 -7.383719
# possorted_genome_bam_W83LZ:TTTGTTGTCTATTGTCx      Early_HY -0.269771 -3.924437
#
# [8669 rows x 3 columns]

# %%
adata_sub.obs = adata_sub.obs.join(new_cell_meta_umap, how="left")

# %%
print(adata_sub.obs.head())
# Out:
#                                                 cell_type    umap_1    umap_2
# CellID
# possorted_genome_bam_W83LZ:AAAGGATTCAGCCTTCx      Late_HY -7.179417  3.192922
# possorted_genome_bam_W83LZ:AAAGAACCATCTTTCAx  LC_ER+_Sca1 -0.580667 -8.247224
# possorted_genome_bam_W83LZ:AAACGAAGTCATATGCx     Early_HY -1.798325 -4.692605
# possorted_genome_bam_W83LZ:AAACCCACATCCCACTx      Late_HY -6.760766  1.335699
# possorted_genome_bam_W83LZ:AAAGGATTCAGCGCACx  LC_ER+_Sca1 -0.561108 -6.228294

# %%
adata_sub.write_loom("filtered_ER_Pik.loom")
