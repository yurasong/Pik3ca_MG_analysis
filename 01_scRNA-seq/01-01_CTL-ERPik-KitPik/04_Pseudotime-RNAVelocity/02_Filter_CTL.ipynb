# %%
import scvelo as scv
import pandas as pd

# %% [markdown]
# # Filteration
#
# ## CTL

# %%
adata = scv.read("../01_Input_file/CTL_raw.loom", cache=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10572 × 32285
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
adata.var_names_make_unique()   # fix duplicate gene names

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [possorted_genome_bam_F2ZHW:AAACGCTAGCGTATGGx, possorted_genome_bam_F2ZHW:AAAGTGAAGACATACAx, possorted_genome_bam_F2ZHW:AAATGGACATTGCCGGx, possorted_genome_bam_F2ZHW:AAACGAAGTGATTCTGx, possorted_genome_bam_F2ZHW:AAACGAAGTCATCACAx, possorted_genome_bam_F2ZHW:AAACGAAGTCGAGATGx, possorted_genome_bam_F2ZHW:AAAGGATGTACAAACAx, possorted_genome_bam_F2ZHW:AAAGTCCAGACATACAx, possorted_genome_bam_F2ZHW:AAAGAACCATACGCATx, possorted_genome_bam_F2ZHW:AAAGGTAAGGTTGAGCx, possorted_genome_bam_F2ZHW:AAACGAAAGAATAGTCx, possorted_genome_bam_F2ZHW:AAAGGGCTCTGTCAGAx, possorted_genome_bam_F2ZHW:AAAGAACAGCGCCTACx, possorted_genome_bam_F2ZHW:AAAGTCCAGTGCTCGCx, possorted_genome_bam_F2ZHW:AAAGGTAAGAAGTCATx, possorted_genome_bam_F2ZHW:AAAGTCCAGACCATTCx, possorted_genome_bam_F2ZHW:AAACGAAGTTTGGAAAx, possorted_genome_bam_F2ZHW:AAACCCACAACTGGTTx, possorted_genome_bam_F2ZHW:AAATGGAGTAGATCGGx, possorted_genome_bam_F2ZHW:AAAGGGCAGCATCAGGx, possorted_genome_bam_F2ZHW:AAACGAAAGACAGTCGx, possorted_genome_bam_F2ZHW:AAAGTGAAGGCCCGTTx, possorted_genome_bam_F2ZHW:AAAGGATGTGGATCGAx, possorted_genome_bam_F2ZHW:AAATGGAAGGGCTTCCx, possorted_genome_bam_F2ZHW:AAAGTGATCTTCTGGCx, possorted_genome_bam_F2ZHW:AAAGTCCCAGCCTACGx, possorted_genome_bam_F2ZHW:AAAGTCCAGATTGATGx, possorted_genome_bam_F2ZHW:AAAGAACTCTAAACGCx, possorted_genome_bam_F2ZHW:AAAGAACAGCACCGTCx, possorted_genome_bam_F2ZHW:AAAGGATCATCGCTCTx, possorted_genome_bam_F2ZHW:AAAGGATTCCCTGTTGx, possorted_genome_bam_F2ZHW:AAACGAAAGGTGAGAAx, possorted_genome_bam_F2ZHW:AAACCCACACTACACAx, possorted_genome_bam_F2ZHW:AAAGGTAGTTATGTCGx, possorted_genome_bam_F2ZHW:AAAGTGAAGGTAAAGGx, possorted_genome_bam_F2ZHW:AAACGAATCGTGTGGCx, possorted_genome_bam_F2ZHW:AAACGCTAGCGAAACCx, possorted_genome_bam_F2ZHW:AAACGAATCTGCCTGTx, possorted_genome_bam_F2ZHW:AAAGGGCCAGACGATGx, possorted_genome_bam_F2ZHW:AAAGTCCCAAGCACAGx, possorted_genome_bam_F2ZHW:AAAGGGCTCGAGTTGTx, possorted_genome_bam_F2ZHW:AAAGGTATCTCGCTTGx, possorted_genome_bam_F2ZHW:AAAGGTATCATACGGTx, possorted_genome_bam_F2ZHW:AAAGAACTCCATCCGTx, possorted_genome_bam_F2ZHW:AAACGAACAGCTCATAx, possorted_genome_bam_F2ZHW:AAACGCTGTAAGTTAGx, possorted_genome_bam_F2ZHW:AAAGGTAGTGACACAGx, possorted_genome_bam_F2ZHW:AAACGAATCTGGGTCGx, possorted_genome_bam_F2ZHW:AAACCCAGTATGACAAx, possorted_genome_bam_F2ZHW:AAAGTCCGTGTTACACx, possorted_genome_bam_F2ZHW:AAACGAAAGACCCGCTx, possorted_genome_bam_F2ZHW:AAACGCTTCGAGCTGCx, possorted_genome_bam_F2ZHW:AAAGGGCAGATGTAGTx, possorted_genome_bam_F2ZHW:AAAGGTAGTGGACTGAx, possorted_genome_bam_F2ZHW:AAAGGATAGAGAGGTAx, possorted_genome_bam_F2ZHW:AAAGGTAAGCTATCTGx, possorted_genome_bam_F2ZHW:AAAGTCCGTGACCGAAx, possorted_genome_bam_F2ZHW:AAAGGGCTCTGAATGCx, possorted_genome_bam_F2ZHW:AAACGAATCAAGTGGGx, possorted_genome_bam_F2ZHW:AAAGAACGTACCCAGCx, possorted_genome_bam_F2ZHW:AAAGTCCGTACGAGTGx, possorted_genome_bam_F2ZHW:AAAGTGATCATCTGTTx, possorted_genome_bam_F2ZHW:AAAGTGACAACCCTCTx, possorted_genome_bam_F2ZHW:AAACCCACAAACGGCAx, possorted_genome_bam_F2ZHW:AAACCCAGTGGCTTATx, possorted_genome_bam_F2ZHW:AAAGGGCAGGTCGACAx, possorted_genome_bam_F2ZHW:AAATGGACACTGGCCAx, possorted_genome_bam_F2ZHW:AAAGTCCAGATTCGAAx, possorted_genome_bam_F2ZHW:AAAGTCCTCCTACGGGx, possorted_genome_bam_F2ZHW:AAATGGAAGCTTCATGx, possorted_genome_bam_F2ZHW:AAACCCAAGGTGCTTTx, possorted_genome_bam_F2ZHW:AAAGGTACAACTGTGTx, possorted_genome_bam_F2ZHW:AAACCCACAAAGGCTGx, possorted_genome_bam_F2ZHW:AAAGTGAGTATCGTTGx, possorted_genome_bam_F2ZHW:AAATGGAAGTCTTCCCx, possorted_genome_bam_F2ZHW:AAAGTCCGTACAAGCGx, possorted_genome_bam_F2ZHW:AAACCCATCGCTGTCTx, possorted_genome_bam_F2ZHW:AAAGTCCCACTGGACCx, possorted_genome_bam_F2ZHW:AAAGGGCTCCCGTGAGx, possorted_genome_bam_F2ZHW:AAAGTGAAGGATGGCTx, possorted_genome_bam_F2ZHW:AAAGTCCAGTGAGGCTx, possorted_genome_bam_F2ZHW:AAATGGACACTACAGTx, possorted_genome_bam_F2ZHW:AAACCCAGTCGCATTAx, possorted_genome_bam_F2ZHW:AAACGAAGTATCGTTGx, possorted_genome_bam_F2ZHW:AAAGGATAGGCTCTATx, possorted_genome_bam_F2ZHW:AAAGAACCACCCAATAx, possorted_genome_bam_F2ZHW:AAAGGGCAG ...
#
# [10572 rows x 0 columns]

# %%
cell_meta = pd.read_csv("meta_ctl.csv")
cell_meta
# Out:
#                     CellID     cell_type
# 0     AAACGAATCAAGTGGG-1_1    LC_ER-_LuP
# 1     AAAGAACTCTAAACGC-1_1           Myo
# 2     AAAGGGCTCTGTCAGA-1_1    LC_ER-_LuP
# 3     AAAGTCCAGTGCTCGC-1_1  LC_ER+_Foxa1
# 4     AAAGTCCCACTGGACC-1_1    LC_ER-_LuP
# ...                    ...           ...
# 1347  TTTGGAGTCTCTCAAT-1_1    LC_ER-_LuP
# 1348  TTTGGTTCACACCGCA-1_1           Myo
# 1349  TTTGGTTGTCACGACC-1_1    LC_ER-_LuP
# 1350  TTTGGTTGTGTACGCC-1_1    LC_ER-_LuP
# 1351  TTTGTTGCACACGGTC-1_1    LC_ER-_LuP
#
# [1352 rows x 2 columns]

# %%
cell_umap = pd.read_csv("umap_ctl.csv", sep=',')
cell_umap
# Out:
#                     CellID    umap_1    umap_2
# 0     AAACGAATCAAGTGGG-1_1  7.519389  6.254953
# 1     AAAGAACTCTAAACGC-1_1 -7.574637 -7.710628
# 2     AAAGGGCTCTGTCAGA-1_1  2.844351  3.001735
# 3     AAAGTCCAGTGCTCGC-1_1  1.854609 -7.134219
# 4     AAAGTCCCACTGGACC-1_1  7.263851  6.731787
# ...                    ...       ...       ...
# 1347  TTTGGAGTCTCTCAAT-1_1  2.397697  3.261179
# 1348  TTTGGTTCACACCGCA-1_1 -8.270704 -8.207389
# 1349  TTTGGTTGTCACGACC-1_1  2.562882  3.069721
# 1350  TTTGGTTGTGTACGCC-1_1  6.640626  7.261545
# 1351  TTTGTTGCACACGGTC-1_1  2.648406  3.487098
#
# [1352 rows x 3 columns]

# %%
cell_meta_umap = pd.merge(cell_meta, cell_umap, on="CellID", how="inner")
cell_meta_umap
# Out:
#                     CellID     cell_type    umap_1    umap_2
# 0     AAACGAATCAAGTGGG-1_1    LC_ER-_LuP  7.519389  6.254953
# 1     AAAGAACTCTAAACGC-1_1           Myo -7.574637 -7.710628
# 2     AAAGGGCTCTGTCAGA-1_1    LC_ER-_LuP  2.844351  3.001735
# 3     AAAGTCCAGTGCTCGC-1_1  LC_ER+_Foxa1  1.854609 -7.134219
# 4     AAAGTCCCACTGGACC-1_1    LC_ER-_LuP  7.263851  6.731787
# ...                    ...           ...       ...       ...
# 1347  TTTGGAGTCTCTCAAT-1_1    LC_ER-_LuP  2.397697  3.261179
# 1348  TTTGGTTCACACCGCA-1_1           Myo -8.270704 -8.207389
# 1349  TTTGGTTGTCACGACC-1_1    LC_ER-_LuP  2.562882  3.069721
# 1350  TTTGGTTGTGTACGCC-1_1    LC_ER-_LuP  6.640626  7.261545
# 1351  TTTGTTGCACACGGTC-1_1    LC_ER-_LuP  2.648406  3.487098
#
# [1352 rows x 4 columns]

# %%
cell_meta_umap.index = cell_meta_umap['CellID']
cell_meta_umap = cell_meta_umap.drop(['CellID'], axis=1)

cell_meta_umap
# Out:
#                          cell_type    umap_1    umap_2
# CellID
# AAACGAATCAAGTGGG-1_1    LC_ER-_LuP  7.519389  6.254953
# AAAGAACTCTAAACGC-1_1           Myo -7.574637 -7.710628
# AAAGGGCTCTGTCAGA-1_1    LC_ER-_LuP  2.844351  3.001735
# AAAGTCCAGTGCTCGC-1_1  LC_ER+_Foxa1  1.854609 -7.134219
# AAAGTCCCACTGGACC-1_1    LC_ER-_LuP  7.263851  6.731787
# ...                            ...       ...       ...
# TTTGGAGTCTCTCAAT-1_1    LC_ER-_LuP  2.397697  3.261179
# TTTGGTTCACACCGCA-1_1           Myo -8.270704 -8.207389
# TTTGGTTGTCACGACC-1_1    LC_ER-_LuP  2.562882  3.069721
# TTTGGTTGTGTACGCC-1_1    LC_ER-_LuP  6.640626  7.261545
# TTTGTTGCACACGGTC-1_1    LC_ER-_LuP  2.648406  3.487098
#
# [1352 rows x 3 columns]

# %%
# loop for cellID

def add_scvelo_ID(df):
    df = df.copy()
    ids = []
    for idx in df.index.astype(str):
        barcode16 = idx.split("-")[0][:16]
        ids.append(f"possorted_genome_bam_F2ZHW:{barcode16}x")
    df["scvelo_cellID"] = ids
    return df

# %%
new_cell_meta_umap = add_scvelo_ID(cell_meta_umap)

# %%
new_cell_meta_umap
# Out:
#                          cell_type    umap_1    umap_2  \
# CellID
# AAACGAATCAAGTGGG-1_1    LC_ER-_LuP  7.519389  6.254953
# AAAGAACTCTAAACGC-1_1           Myo -7.574637 -7.710628
# AAAGGGCTCTGTCAGA-1_1    LC_ER-_LuP  2.844351  3.001735
# AAAGTCCAGTGCTCGC-1_1  LC_ER+_Foxa1  1.854609 -7.134219
# AAAGTCCCACTGGACC-1_1    LC_ER-_LuP  7.263851  6.731787
# ...                            ...       ...       ...
# TTTGGAGTCTCTCAAT-1_1    LC_ER-_LuP  2.397697  3.261179
# TTTGGTTCACACCGCA-1_1           Myo -8.270704 -8.207389
# TTTGGTTGTCACGACC-1_1    LC_ER-_LuP  2.562882  3.069721
# TTTGGTTGTGTACGCC-1_1    LC_ER-_LuP  6.640626  7.261545
# TTTGTTGCACACGGTC-1_1    LC_ER-_LuP  2.648406  3.487098
#
#                                                      scvelo_cellID
# CellID
# AAACGAATCAAGTGGG-1_1  possorted_genome_bam_F2ZHW:AAACGAATCAAGTGGGx
# AAAGAACTCTAAACGC-1_1  possorted_genome_bam_F2ZHW:AAAGAACTCTAAACGCx
# AAAGGGCTCTGTCAGA-1_1  possorted_genome_bam_F2ZHW:AAAGGGCTCTGTCAGAx
# AAAGTCCAGTGCTCGC-1_1  possorted_genome_bam_F2ZHW:AAAGTCCAGTGCTCGCx
# AAAGTCCCACTGGACC-1_1  possorted_genome_bam_F2ZHW:AAAGTCCCACTGGACCx
# ...                                                            ...
# TTTGGAGTCTCTCAAT-1_1  possorted_genome_bam_F2ZHW:TTTGGAGTCTCTCAATx
# TTTGGTTCACACCGCA-1_1  possorted_genome_bam_F2ZHW:TTTGGTTCACACCGCAx
# TTTGGTTGTCACGACC-1_1  possorted_genome_bam_F2ZHW:TTTGGTTGTCACGACCx
# TTTGGTTGTGTACGCC-1_1  possorted_genome_bam_F2ZHW:TTTGGTTGTGTACGCCx
# TTTGTTGCACACGGTC-1_1  possorted_genome_bam_F2ZHW:TTTGTTGCACACGGTCx
#
# [1352 rows x 4 columns]

# %%
print(adata.obs_names[:5])
# Out:
# Index(['possorted_genome_bam_F2ZHW:AAACGCTAGCGTATGGx',
#        'possorted_genome_bam_F2ZHW:AAAGTGAAGACATACAx',
#        'possorted_genome_bam_F2ZHW:AAATGGACATTGCCGGx',
#        'possorted_genome_bam_F2ZHW:AAACGAAGTGATTCTGx',
#        'possorted_genome_bam_F2ZHW:AAACGAAGTCATCACAx'],
#       dtype='object', name='CellID')

# %%
valid_cells = new_cell_meta_umap["scvelo_cellID"].values
adata_sub = adata[adata.obs_names.isin(valid_cells)].copy()

# %%
print(f"Original cells: {adata.n_obs}, Filtered cells: {adata_sub.n_obs}")
# Out:
# Original cells: 10572, Filtered cells: 1352

# %%
new_cell_meta_umap.index = new_cell_meta_umap['scvelo_cellID']
new_cell_meta_umap = new_cell_meta_umap.drop(['scvelo_cellID'], axis=1)

# %%
new_cell_meta_umap
# Out:
#                                                  cell_type    umap_1    umap_2
# scvelo_cellID
# possorted_genome_bam_F2ZHW:AAACGAATCAAGTGGGx    LC_ER-_LuP  7.519389  6.254953
# possorted_genome_bam_F2ZHW:AAAGAACTCTAAACGCx           Myo -7.574637 -7.710628
# possorted_genome_bam_F2ZHW:AAAGGGCTCTGTCAGAx    LC_ER-_LuP  2.844351  3.001735
# possorted_genome_bam_F2ZHW:AAAGTCCAGTGCTCGCx  LC_ER+_Foxa1  1.854609 -7.134219
# possorted_genome_bam_F2ZHW:AAAGTCCCACTGGACCx    LC_ER-_LuP  7.263851  6.731787
# ...                                                    ...       ...       ...
# possorted_genome_bam_F2ZHW:TTTGGAGTCTCTCAATx    LC_ER-_LuP  2.397697  3.261179
# possorted_genome_bam_F2ZHW:TTTGGTTCACACCGCAx           Myo -8.270704 -8.207389
# possorted_genome_bam_F2ZHW:TTTGGTTGTCACGACCx    LC_ER-_LuP  2.562882  3.069721
# possorted_genome_bam_F2ZHW:TTTGGTTGTGTACGCCx    LC_ER-_LuP  6.640626  7.261545
# possorted_genome_bam_F2ZHW:TTTGTTGCACACGGTCx    LC_ER-_LuP  2.648406  3.487098
#
# [1352 rows x 3 columns]

# %%
adata_sub.obs = adata_sub.obs.join(new_cell_meta_umap, how="left")

# %%
print(adata_sub.obs.head())
# Out:
#                                                  cell_type    umap_1    umap_2
# CellID
# possorted_genome_bam_F2ZHW:AAAGGGCTCTGTCAGAx    LC_ER-_LuP  2.844351  3.001735
# possorted_genome_bam_F2ZHW:AAAGTCCAGTGCTCGCx  LC_ER+_Foxa1  1.854609 -7.134219
# possorted_genome_bam_F2ZHW:AAAGAACTCTAAACGCx           Myo -7.574637 -7.710628
# possorted_genome_bam_F2ZHW:AAACGAATCAAGTGGGx    LC_ER-_LuP  7.519389  6.254953
# possorted_genome_bam_F2ZHW:AAAGTCCGTACGAGTGx    LC_ER-_LuP  8.172050  6.475503

# %%
adata_sub.write_loom("filtered_CTL.loom")
